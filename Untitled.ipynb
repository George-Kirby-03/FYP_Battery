# %%
import os
import numpy as np
import pandas as pd
import torch
from torch import nn
from torch.utils.data import Dataset, DataLoader
import matplotlib.pyplot as plt

# ------------------------------
# USER CONFIG
# ------------------------------
DATA_DIR = "cycle_exports"  # folder containing per-cycle CSVs
PREDICT_OFFSET = 20                   # predict voltage N cycles ahead
SEQ_LEN = 2000                        # resample each cycle to this many points
EPOCHS = 1000
BATCH_SIZE = 32
LR = 1e-3
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
if DEVICE == "cuda":
    print("Yay")

# ------------------------------
# 1️⃣ Load and resample data
# ------------------------------
def resample_cycle(df, seq_len):
    """Resample cycle to fixed seq_len points."""
    df = df.sort_values("TestTime")
    t = df["TestTime"].values
    new_t = np.linspace(t.min(), t.max(), seq_len)
    def interp(col):
        if col not in df:  # handle missing temp
            return np.zeros(seq_len)
        return np.interp(new_t, t, df[col].values)
    current = interp("Amps")
    voltage = interp("Volts")
    temp = interp("temp") if "temp" in df.columns else np.zeros(seq_len)
    return current, voltage, temp

def load_cycles(folder):
    files = sorted([f for f in os.listdir(folder) if f.endswith(".csv")])
    currents, voltages, temps = [], [], []
    for f in files:
        df = pd.read_csv(os.path.join(folder, f))
        c, v, t = resample_cycle(df, SEQ_LEN)
        currents.append(c)
        voltages.append(v)
        temps.append(t)
    return np.array(currents), np.array(voltages), np.array(temps)

currents, voltages, temps = load_cycles(DATA_DIR)
print(f"Loaded {len(currents)} cycles")

# ------------------------------
# 2️⃣ Dataset
# ------------------------------
class BatteryDataset(Dataset):
    def __init__(self, currents, voltages, temps, offset):
        self.currents = currents
        self.voltages = voltages
        self.temps = temps
        self.offset = offset
        self.n = len(currents) - offset

    def __len__(self):
        return self.n

    def __getitem__(self, idx):
        # input = [current_i, voltage_i, temp_i]
        X = np.stack([self.currents[idx], self.voltages[idx], self.temps[idx]], axis=-1)
        # target = voltage of future cycle
        y = self.voltages[idx + self.offset][..., None]
        return torch.tensor(X, dtype=torch.float32), torch.tensor(y, dtype=torch.float32)

dataset = BatteryDataset(currents, voltages, temps, PREDICT_OFFSET)
train_loader = DataLoader(dataset, batch_size=BATCH_SIZE, shuffle=True)

# ------------------------------
# 3️⃣ LSTM Model
# ------------------------------
class BatteryLSTM(nn.Module):
    def __init__(self, input_size=3, hidden_size=128, num_layers=2, output_size=1):
        super().__init__()
        self.lstm = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True)
        self.fc = nn.Linear(hidden_size, output_size)
    def forward(self, x):
        out, _ = self.lstm(x)
        out = self.fc(out)
        return out

model = BatteryLSTM().to(DEVICE)
loss_fn = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=LR)

# ------------------------------
# 4️⃣ Training
# ------------------------------
for epoch in range(EPOCHS):
    total_loss = 0
    for X, y in train_loader:
        X, y = X.to(DEVICE), y.to(DEVICE)
        pred = model(X)
        loss = loss_fn(pred, y)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        total_loss += loss.item()
    print(f"Epoch {epoch+1}: loss={total_loss/len(train_loader):.6f}")

# ------------------------------
# 5️⃣ Test with a random example
# ------------------------------
model.eval()
idx = np.random.randint(0, len(dataset))
with torch.no_grad():
    X, y_true = dataset[idx]
    pred = model(X.unsqueeze(0).to(DEVICE)).cpu().squeeze().numpy()
    true = y_true.squeeze().numpy()

plt.figure(figsize=(8,4))
plt.plot(true, label=f"True Voltage (Cycle {idx+PREDICT_OFFSET})")
plt.plot(pred, label="Predicted Voltage")
plt.title("Predicted vs True Future Voltage")
plt.legend()
plt.show()
# Out:
# Loaded 88 cycles
# Epoch 1: loss=13.621717
# Epoch 2: loss=11.732156
# Epoch 3: loss=7.929624
# Epoch 4: loss=1.905181
# Epoch 5: loss=0.231024
# Epoch 6: loss=0.594860
# Epoch 7: loss=0.489890
# Epoch 8: loss=0.218811
# Epoch 9: loss=0.153644
# Epoch 10: loss=0.225942
# Epoch 11: loss=0.234359
# Epoch 12: loss=0.175195
# Epoch 13: loss=0.140247
# Epoch 14: loss=0.150910
# Epoch 15: loss=0.161984
# Epoch 16: loss=0.152792
# Epoch 17: loss=0.139780
# Epoch 18: loss=0.138479
# Epoch 19: loss=0.143280
# Epoch 20: loss=0.142032
# Epoch 21: loss=0.137289
# Epoch 22: loss=0.136693
# Epoch 23: loss=0.137709
# Epoch 24: loss=0.136957
# Epoch 25: loss=0.134240
# Epoch 26: loss=0.133736
# Epoch 27: loss=0.131957
# Epoch 28: loss=0.128508
# Epoch 29: loss=0.122516
# Epoch 30: loss=0.117072
# Epoch 31: loss=0.113067
# Epoch 32: loss=0.108838
# Epoch 33: loss=0.107123
# Epoch 34: loss=0.103362
# Epoch 35: loss=0.099425
# Epoch 36: loss=0.096475
# Epoch 37: loss=0.093151
# Epoch 38: loss=0.089841
# Epoch 39: loss=0.087773
# Epoch 40: loss=0.083866
# Epoch 41: loss=0.081508
# Epoch 42: loss=0.079340
# Epoch 43: loss=0.075940
# Epoch 44: loss=0.072332
# Epoch 45: loss=0.067487
# Epoch 46: loss=0.061944
# Epoch 47: loss=0.153814
# Epoch 48: loss=0.152685
# Epoch 49: loss=0.139160
# Epoch 50: loss=0.153916
# Epoch 51: loss=0.141809
# Epoch 52: loss=0.134818
# Epoch 53: loss=0.140847
# Epoch 54: loss=0.136439
# Epoch 55: loss=0.133068
# Epoch 56: loss=0.134843
# Epoch 57: loss=0.132507
# Epoch 58: loss=0.130560
# Epoch 59: loss=0.129671
# Epoch 60: loss=0.126531
# Epoch 61: loss=0.123072
# Epoch 62: loss=0.117302
# Epoch 63: loss=0.109345
# Epoch 64: loss=0.102661
# Epoch 65: loss=0.094424
# Epoch 66: loss=0.083908
# Epoch 67: loss=0.075823
# Epoch 68: loss=0.162089
# Epoch 69: loss=0.129467
# Epoch 70: loss=0.145487
# Epoch 71: loss=0.128778
# Epoch 72: loss=0.129515
# Epoch 73: loss=0.124265
# Epoch 74: loss=0.121464
# Epoch 75: loss=0.113882
# Epoch 76: loss=0.106995
# Epoch 77: loss=0.094655
# Epoch 78: loss=0.080124
# Epoch 79: loss=0.070428
# Epoch 80: loss=0.060612
# Epoch 81: loss=0.054919
# Epoch 82: loss=0.053165
# Epoch 83: loss=0.048443
# Epoch 84: loss=0.098575
# Epoch 85: loss=0.080699
# Epoch 86: loss=0.080770
# Epoch 87: loss=0.075076
# Epoch 88: loss=0.078074
# Epoch 89: loss=0.063010
# Epoch 90: loss=0.063424
# Epoch 91: loss=0.055926
# Epoch 92: loss=0.055160
# Epoch 93: loss=0.049645
# Epoch 94: loss=0.047539
# Epoch 95: loss=0.046432
# Epoch 96: loss=0.044994
# Epoch 97: loss=0.041795
# Epoch 98: loss=0.039662
# Epoch 99: loss=0.036617
# Epoch 100: loss=0.032320
# Epoch 101: loss=0.028456
# Epoch 102: loss=0.033228
# Epoch 103: loss=0.036134
# Epoch 104: loss=0.035660
# Epoch 105: loss=0.032836
# Epoch 106: loss=0.031192
# Epoch 107: loss=0.028762
# Epoch 108: loss=0.033706
# Epoch 109: loss=0.031195
# Epoch 110: loss=0.028888
# Epoch 111: loss=0.029594
# Epoch 112: loss=0.025453
# Epoch 113: loss=0.025645
# Epoch 114: loss=0.025995
# Epoch 115: loss=0.025471
# Epoch 116: loss=0.026356
# Epoch 117: loss=0.026968
# Epoch 118: loss=0.026482
# Epoch 119: loss=0.025158
# Epoch 120: loss=0.026626
# Epoch 121: loss=0.031342
# Epoch 122: loss=0.032119
# Epoch 123: loss=0.028290
# Epoch 124: loss=0.033487
# Epoch 125: loss=0.029591
# Epoch 126: loss=0.022922
# Epoch 127: loss=0.022942
# Epoch 128: loss=0.022148
# Epoch 129: loss=0.020575
# Epoch 130: loss=0.019226
# Epoch 131: loss=0.016639
# Epoch 132: loss=0.016315
# Epoch 133: loss=0.014943
# Epoch 134: loss=0.013446
# Epoch 135: loss=0.013074
# Epoch 136: loss=0.012335
# Epoch 137: loss=0.011202
# Epoch 138: loss=0.011163
# Epoch 139: loss=0.010696
# Epoch 140: loss=0.011606
# Epoch 141: loss=0.013336
# Epoch 142: loss=0.012199
# Epoch 143: loss=0.011941
# Epoch 144: loss=0.010975
# Epoch 145: loss=0.011017
# Epoch 146: loss=0.010379
# Epoch 147: loss=0.010375
# Epoch 148: loss=0.010077
# Epoch 149: loss=0.009841
# Epoch 150: loss=0.009894
# Epoch 151: loss=0.009747
# Epoch 152: loss=0.009840
# Epoch 153: loss=0.009306
# Epoch 154: loss=0.009390
# Epoch 155: loss=0.009635
# Epoch 156: loss=0.010083
# Epoch 157: loss=0.009625
# Epoch 158: loss=0.009930
# Epoch 159: loss=0.009468
# Epoch 160: loss=0.009332
# Epoch 161: loss=0.009585
# Epoch 162: loss=0.009559
# Epoch 163: loss=0.009320
# Epoch 164: loss=0.009480
# Epoch 165: loss=0.009169
# Epoch 166: loss=0.009096
# Epoch 167: loss=0.008893
# Epoch 168: loss=0.008884
# Epoch 169: loss=0.008751
# Epoch 170: loss=0.009093
# Epoch 171: loss=0.008693
# Epoch 172: loss=0.008843
# Epoch 173: loss=0.009096
# Epoch 174: loss=0.009073
# Epoch 175: loss=0.008981
# Epoch 176: loss=0.008514
# Epoch 177: loss=0.008564
# Epoch 178: loss=0.008714
# Epoch 179: loss=0.008570
# Epoch 180: loss=0.008616
# Epoch 181: loss=0.008507
# Epoch 182: loss=0.008924
# Epoch 183: loss=0.009029
# Epoch 184: loss=0.008709
# Epoch 185: loss=0.008422
# Epoch 186: loss=0.008425
# Epoch 187: loss=0.008566
# Epoch 188: loss=0.008724
# Epoch 189: loss=0.009245
# Epoch 190: loss=0.009148
# Epoch 191: loss=0.008753
# Epoch 192: loss=0.008651
# Epoch 193: loss=0.008470
# Epoch 194: loss=0.008249
# Epoch 195: loss=0.008254
# Epoch 196: loss=0.008378
# Epoch 197: loss=0.008540
# Epoch 198: loss=0.008342
# Epoch 199: loss=0.008315
# Epoch 200: loss=0.008229
# Epoch 201: loss=0.008072
# Epoch 202: loss=0.008028
# Epoch 203: loss=0.008118
# Epoch 204: loss=0.008386
# Epoch 205: loss=0.008430
# Epoch 206: loss=0.008354
# Epoch 207: loss=0.008314
# Epoch 208: loss=0.008080
# Epoch 209: loss=0.008430
# Epoch 210: loss=0.008116
# Epoch 211: loss=0.008138
# Epoch 212: loss=0.007776
# Epoch 213: loss=0.007566
# Epoch 214: loss=0.007592
# Epoch 215: loss=0.007721
# Epoch 216: loss=0.008057
# Epoch 217: loss=0.008016
# Epoch 218: loss=0.007861
# Epoch 219: loss=0.007725
# Epoch 220: loss=0.007560
# Epoch 221: loss=0.007964
# Epoch 222: loss=0.008273
# Epoch 223: loss=0.008515
# Epoch 224: loss=0.008498
# Epoch 225: loss=0.008457
# Epoch 226: loss=0.007728
# Epoch 227: loss=0.007878
# Epoch 228: loss=0.007629
# Epoch 229: loss=0.008017
# Epoch 230: loss=0.007497
# Epoch 231: loss=0.007547
# Epoch 232: loss=0.007913
# Epoch 233: loss=0.007664
# Epoch 234: loss=0.008337
# Epoch 235: loss=0.007910
# Epoch 236: loss=0.007412
# Epoch 237: loss=0.006971
# Epoch 238: loss=0.007234
# Epoch 239: loss=0.007488
# Epoch 240: loss=0.007256
# Epoch 241: loss=0.007422
# Epoch 242: loss=0.007639
# Epoch 243: loss=0.007501
# Epoch 244: loss=0.007362
# Epoch 245: loss=0.007205
# Epoch 246: loss=0.007199
# Epoch 247: loss=0.007196
# Epoch 248: loss=0.007105
# Epoch 249: loss=0.006985
# Epoch 250: loss=0.006823
# Epoch 251: loss=0.006764
# Epoch 252: loss=0.007024
# Epoch 253: loss=0.007109
# Epoch 254: loss=0.006954
# Epoch 255: loss=0.006978
# Epoch 256: loss=0.007306
# Epoch 257: loss=0.006838
# Epoch 258: loss=0.006792
# Epoch 259: loss=0.007312
# Epoch 260: loss=0.006780
# Epoch 261: loss=0.006941
# Epoch 262: loss=0.006549
# Epoch 263: loss=0.006496
# Epoch 264: loss=0.006508
# Epoch 265: loss=0.006463
# Epoch 266: loss=0.006528
# Epoch 267: loss=0.006346
# Epoch 268: loss=0.006523
# Epoch 269: loss=0.006387
# Epoch 270: loss=0.006250
# Epoch 271: loss=0.006255
# Epoch 272: loss=0.006325
# Epoch 273: loss=0.006192
# Epoch 274: loss=0.006193
# Epoch 275: loss=0.006528
# Epoch 276: loss=0.006480
# Epoch 277: loss=0.006538
# Epoch 278: loss=0.005972
# Epoch 279: loss=0.006237
# Epoch 280: loss=0.006243
# Epoch 281: loss=0.006124
# Epoch 282: loss=0.006720
# Epoch 283: loss=0.006300
# Epoch 284: loss=0.006315
# Epoch 285: loss=0.006834
# Epoch 286: loss=0.006581
# Epoch 287: loss=0.006659
# Epoch 288: loss=0.006089
# Epoch 289: loss=0.005870
# Epoch 290: loss=0.005860
# Epoch 291: loss=0.005944
# Epoch 292: loss=0.006259
# Epoch 293: loss=0.005784
# Epoch 294: loss=0.006145
# Epoch 295: loss=0.006179
# Epoch 296: loss=0.005695
# Epoch 297: loss=0.006003
# Epoch 298: loss=0.005785
# Epoch 299: loss=0.006769
# Epoch 300: loss=0.005994
# Epoch 301: loss=0.005689
# Epoch 302: loss=0.005712
# Epoch 303: loss=0.005905
# Epoch 304: loss=0.006077
# Epoch 305: loss=0.006132
# Epoch 306: loss=0.005560
# Epoch 307: loss=0.005546
# Epoch 308: loss=0.006563
# Epoch 309: loss=0.006640
# Epoch 310: loss=0.006090
# Epoch 311: loss=0.005616
# Epoch 312: loss=0.005583
# Epoch 313: loss=0.005686
# Epoch 314: loss=0.005637
# Epoch 315: loss=0.005503
# Epoch 316: loss=0.005707
# Epoch 317: loss=0.005494
# Epoch 318: loss=0.005622
# Epoch 319: loss=0.005491
# Epoch 320: loss=0.005349
# Epoch 321: loss=0.005430
# Epoch 322: loss=0.004953
# Epoch 323: loss=0.005568
# Epoch 324: loss=0.005139
# Epoch 325: loss=0.005027
# Epoch 326: loss=0.005125
# Epoch 327: loss=0.005122
# Epoch 328: loss=0.004969
# Epoch 329: loss=0.005074
# Epoch 330: loss=0.004768
# Epoch 331: loss=0.005011
# Epoch 332: loss=0.005359
# Epoch 333: loss=0.004914
# Epoch 334: loss=0.004974
# Epoch 335: loss=0.005252
# Epoch 336: loss=0.004911
# Epoch 337: loss=0.004720
# Epoch 338: loss=0.004966
# Epoch 339: loss=0.005496
# Epoch 340: loss=0.005845
# Epoch 341: loss=0.004763
# Epoch 342: loss=0.005336
# Epoch 343: loss=0.004920
# Epoch 344: loss=0.004905
# Epoch 345: loss=0.004787
# Epoch 346: loss=0.004506
# Epoch 347: loss=0.004586
# Epoch 348: loss=0.004593
# Epoch 349: loss=0.004909
# Epoch 350: loss=0.004791
# Epoch 351: loss=0.004586
# Epoch 352: loss=0.004641
# Epoch 353: loss=0.004570
# Epoch 354: loss=0.004503
# Epoch 355: loss=0.004478
# Epoch 356: loss=0.004455
# Epoch 357: loss=0.004469
# Epoch 358: loss=0.004720
# Epoch 359: loss=0.005194
# Epoch 360: loss=0.004712
# Epoch 361: loss=0.004673
# Epoch 362: loss=0.005054
# Epoch 363: loss=0.004607
# Epoch 364: loss=0.004527
# Epoch 365: loss=0.004398
# Epoch 366: loss=0.004497
# Epoch 367: loss=0.004517
# Epoch 368: loss=0.004504
# Epoch 369: loss=0.004541
# Epoch 370: loss=0.004368
# Epoch 371: loss=0.004122
# Epoch 372: loss=0.004335
# Epoch 373: loss=0.004543
# Epoch 374: loss=0.004731
# Epoch 375: loss=0.004511
# Epoch 376: loss=0.004490
# Epoch 377: loss=0.004294
# Epoch 378: loss=0.003913
# Epoch 379: loss=0.004080
# Epoch 380: loss=0.003896
# Epoch 381: loss=0.004409
# Epoch 382: loss=0.004227
# Epoch 383: loss=0.003813
# Epoch 384: loss=0.003935
# Epoch 385: loss=0.004014
# Epoch 386: loss=0.003869
# Epoch 387: loss=0.003883
# Epoch 388: loss=0.003903
# Epoch 389: loss=0.003972
# Epoch 390: loss=0.004282
# Epoch 391: loss=0.004049
# Epoch 392: loss=0.003992
# Epoch 393: loss=0.004267
# Epoch 394: loss=0.003995
# Epoch 395: loss=0.003860
# Epoch 396: loss=0.004047
# Epoch 397: loss=0.004005
# Epoch 398: loss=0.003954
# Epoch 399: loss=0.003828
# Epoch 400: loss=0.003848
# Epoch 401: loss=0.003675
# Epoch 402: loss=0.003608
# Epoch 403: loss=0.003562
# Epoch 404: loss=0.003907
# Epoch 405: loss=0.003711
# Epoch 406: loss=0.003781
# Epoch 407: loss=0.003800
# Epoch 408: loss=0.003594
# Epoch 409: loss=0.003526
# Epoch 410: loss=0.003799
# Epoch 411: loss=0.003707
# Epoch 412: loss=0.003351
# Epoch 413: loss=0.003667
# Epoch 414: loss=0.003652
# Epoch 415: loss=0.003673
# Epoch 416: loss=0.003469
# Epoch 417: loss=0.003578
# Epoch 418: loss=0.003450
# Epoch 419: loss=0.003440
# Epoch 420: loss=0.003524
# Epoch 421: loss=0.004318
# Epoch 422: loss=0.004234
# Epoch 423: loss=0.003615
# Epoch 424: loss=0.003535
# Epoch 425: loss=0.003252
# Epoch 426: loss=0.003484
# Epoch 427: loss=0.003622
# Epoch 428: loss=0.003785
# Epoch 429: loss=0.003562
# Epoch 430: loss=0.003732
# Epoch 431: loss=0.003484
# Epoch 432: loss=0.003476
# Epoch 433: loss=0.003534
# Epoch 434: loss=0.003375
# Epoch 435: loss=0.003165
# Epoch 436: loss=0.003080
# Epoch 437: loss=0.003209
# Epoch 438: loss=0.003423
# Epoch 439: loss=0.003589
# Epoch 440: loss=0.003319
# Epoch 441: loss=0.003419
# Epoch 442: loss=0.003288
# Epoch 443: loss=0.003414
# Epoch 444: loss=0.003301
# Epoch 445: loss=0.003301
# Epoch 446: loss=0.003793
# Epoch 447: loss=0.003895
# Epoch 448: loss=0.003435
# Epoch 449: loss=0.003260
# Epoch 450: loss=0.002974
# Epoch 451: loss=0.003311
# Epoch 452: loss=0.003420
# Epoch 453: loss=0.002988
# Epoch 454: loss=0.003411
# Epoch 455: loss=0.003465
# Epoch 456: loss=0.003116
# Epoch 457: loss=0.003705
# Epoch 458: loss=0.003204
# Epoch 459: loss=0.003665
# Epoch 460: loss=0.004515
# Epoch 461: loss=0.003338
# Epoch 462: loss=0.004276
# Epoch 463: loss=0.003813
# Epoch 464: loss=0.003417
# Epoch 465: loss=0.003629
# Epoch 466: loss=0.003177
# Epoch 467: loss=0.003806
# Epoch 468: loss=0.003051
# Epoch 469: loss=0.002914
# Epoch 470: loss=0.002999
# Epoch 471: loss=0.002933
# Epoch 472: loss=0.003063
# Epoch 473: loss=0.002866
# Epoch 474: loss=0.003209
# Epoch 475: loss=0.003155
# Epoch 476: loss=0.003449
# Epoch 477: loss=0.003142
# Epoch 478: loss=0.003082
# Epoch 479: loss=0.003675
# Epoch 480: loss=0.003228
# Epoch 481: loss=0.002964
# Epoch 482: loss=0.002839
# Epoch 483: loss=0.002947
# Epoch 484: loss=0.002703
# Epoch 485: loss=0.002877
# Epoch 486: loss=0.003089
# Epoch 487: loss=0.002793
# Epoch 488: loss=0.002840
# Epoch 489: loss=0.002803
# Epoch 490: loss=0.002824
# Epoch 491: loss=0.002814
# Epoch 492: loss=0.002881
# Epoch 493: loss=0.002557
# Epoch 494: loss=0.002976
# Epoch 495: loss=0.002830
# Epoch 496: loss=0.002562
# Epoch 497: loss=0.002817
# Epoch 498: loss=0.002479
# Epoch 499: loss=0.002718
# Epoch 500: loss=0.002861
# Epoch 501: loss=0.002838
# Epoch 502: loss=0.002495
# Epoch 503: loss=0.002906
# Epoch 504: loss=0.002902
# Epoch 505: loss=0.002731
# Epoch 506: loss=0.002593
# Epoch 507: loss=0.002716
# Epoch 508: loss=0.002858
# Epoch 509: loss=0.002902
# Epoch 510: loss=0.002759
# Epoch 511: loss=0.003368
# Epoch 512: loss=0.003000
# Epoch 513: loss=0.002880
# Epoch 514: loss=0.003074
# Epoch 515: loss=0.002605
# Epoch 516: loss=0.002637
# Epoch 517: loss=0.002525
# Epoch 518: loss=0.002529
# Epoch 519: loss=0.002489
# Epoch 520: loss=0.002652
# Epoch 521: loss=0.002669
# Epoch 522: loss=0.002416
# Epoch 523: loss=0.002262
# Epoch 524: loss=0.002392
# Epoch 525: loss=0.002439
# Epoch 526: loss=0.002303
# Epoch 527: loss=0.002458
# Epoch 528: loss=0.002559
# Epoch 529: loss=0.002732
# Epoch 530: loss=0.002800
# Epoch 531: loss=0.002746
# Epoch 532: loss=0.002462
# Epoch 533: loss=0.002239
# Epoch 534: loss=0.002299
# Epoch 535: loss=0.002236
# Epoch 536: loss=0.002171
# Epoch 537: loss=0.002465
# Epoch 538: loss=0.002501
# Epoch 539: loss=0.002400
# Epoch 540: loss=0.002260
# Epoch 541: loss=0.002162
# Epoch 542: loss=0.002244
# Epoch 543: loss=0.002324
# Epoch 544: loss=0.002323
# Epoch 545: loss=0.002325
# Epoch 546: loss=0.002492
# Epoch 547: loss=0.002324
# Epoch 548: loss=0.002376
# Epoch 549: loss=0.002173
# Epoch 550: loss=0.002172
# Epoch 551: loss=0.002075
# Epoch 552: loss=0.002208
# Epoch 553: loss=0.002098
# Epoch 554: loss=0.002304
# Epoch 555: loss=0.002518
# Epoch 556: loss=0.002356
# Epoch 557: loss=0.002413
# Epoch 558: loss=0.002354
# Epoch 559: loss=0.001975
# Epoch 560: loss=0.002096
# Epoch 561: loss=0.002106
# Epoch 562: loss=0.002020
# Epoch 563: loss=0.002073
# Epoch 564: loss=0.002370
# Epoch 565: loss=0.002187
# Epoch 566: loss=0.002313
# Epoch 567: loss=0.002048
# Epoch 568: loss=0.002380
# Epoch 569: loss=0.002332
# Epoch 570: loss=0.002232
# Epoch 571: loss=0.002791
# Epoch 572: loss=0.002287
# Epoch 573: loss=0.002409
# Epoch 574: loss=0.001983
# Epoch 575: loss=0.001858
# Epoch 576: loss=0.002262
# Epoch 577: loss=0.002223
# Epoch 578: loss=0.002117
# Epoch 579: loss=0.001857
# Epoch 580: loss=0.002059
# Epoch 581: loss=0.002560
# Epoch 582: loss=0.002091
# Epoch 583: loss=0.002187
# Epoch 584: loss=0.001870
# Epoch 585: loss=0.001986
# Epoch 586: loss=0.001801
# Epoch 587: loss=0.001974
# Epoch 588: loss=0.002066
# Epoch 589: loss=0.001904
# Epoch 590: loss=0.001987
# Epoch 591: loss=0.002251
# Epoch 592: loss=0.002361
# Epoch 593: loss=0.002129
# Epoch 594: loss=0.002050
# Epoch 595: loss=0.001949
# Epoch 596: loss=0.002141
# Epoch 597: loss=0.001817
# Epoch 598: loss=0.001958
# Epoch 599: loss=0.001974
# Epoch 600: loss=0.001994
# Epoch 601: loss=0.002851
# Epoch 602: loss=0.002171
# Epoch 603: loss=0.002507
# Epoch 604: loss=0.002648
# Epoch 605: loss=0.002368
# Epoch 606: loss=0.002352
# Epoch 607: loss=0.002026
# Epoch 608: loss=0.001816
# Epoch 609: loss=0.002103
# Epoch 610: loss=0.001961
# Epoch 611: loss=0.001799
# Epoch 612: loss=0.001679
# Epoch 613: loss=0.001638
# Epoch 614: loss=0.001804
# Epoch 615: loss=0.001691
# Epoch 616: loss=0.001797
# Epoch 617: loss=0.001831
# Epoch 618: loss=0.001886
# Epoch 619: loss=0.001723
# Epoch 620: loss=0.001881
# Epoch 621: loss=0.001858
# Epoch 622: loss=0.001596
# Epoch 623: loss=0.001785
# Epoch 624: loss=0.001915
# Epoch 625: loss=0.001744
# Epoch 626: loss=0.001823
# Epoch 627: loss=0.002030
# Epoch 628: loss=0.001795
# Epoch 629: loss=0.001592
# Epoch 630: loss=0.001573
# Epoch 631: loss=0.001577
# Epoch 632: loss=0.001842
# Epoch 633: loss=0.002011
# Epoch 634: loss=0.001662
# Epoch 635: loss=0.001943
# Epoch 636: loss=0.001849
# Epoch 637: loss=0.001786
# Epoch 638: loss=0.001655
# Epoch 639: loss=0.001751
# Epoch 640: loss=0.001661
# Epoch 641: loss=0.001708
# Epoch 642: loss=0.001627
# Epoch 643: loss=0.001769
# Epoch 644: loss=0.001646
# Epoch 645: loss=0.001710
# Epoch 646: loss=0.001772
# Epoch 647: loss=0.001540
# Epoch 648: loss=0.001683
# Epoch 649: loss=0.002127
# Epoch 650: loss=0.002019
# Epoch 651: loss=0.001523
# Epoch 652: loss=0.001824
# Epoch 653: loss=0.002430
# Epoch 654: loss=0.001753
# Epoch 655: loss=0.002293
# Epoch 656: loss=0.001900
# Epoch 657: loss=0.002006
# Epoch 658: loss=0.001658
# Epoch 659: loss=0.001701
# Epoch 660: loss=0.001484
# Epoch 661: loss=0.001542
# Epoch 662: loss=0.001458
# Epoch 663: loss=0.001647
# Epoch 664: loss=0.001435
# Epoch 665: loss=0.001693
# Epoch 666: loss=0.001561
# Epoch 667: loss=0.001607
# Epoch 668: loss=0.001909
# Epoch 669: loss=0.001960
# Epoch 670: loss=0.001867
# Epoch 671: loss=0.001632
# Epoch 672: loss=0.001855
# Epoch 673: loss=0.001978
# Epoch 674: loss=0.001856
# Epoch 675: loss=0.001458
# Epoch 676: loss=0.001734
# Epoch 677: loss=0.001793
# Epoch 678: loss=0.001811
# Epoch 679: loss=0.001728
# Epoch 680: loss=0.001595
# Epoch 681: loss=0.002296
# Epoch 682: loss=0.002017
# Epoch 683: loss=0.001608
# Epoch 684: loss=0.001499
# Epoch 685: loss=0.001398
# Epoch 686: loss=0.001587
# Epoch 687: loss=0.001576
# Epoch 688: loss=0.001524
# Epoch 689: loss=0.001628
# Epoch 690: loss=0.001816
# Epoch 691: loss=0.001603
# Epoch 692: loss=0.001495
# Epoch 693: loss=0.001726
# Epoch 694: loss=0.001889
# Epoch 695: loss=0.001614
# Epoch 696: loss=0.001869
# Epoch 697: loss=0.002128
# Epoch 698: loss=0.001508
# Epoch 699: loss=0.001612
# Epoch 700: loss=0.001560
# Epoch 701: loss=0.001600
# Epoch 702: loss=0.001620
# Epoch 703: loss=0.001589
# Epoch 704: loss=0.001282
# Epoch 705: loss=0.001635
# Epoch 706: loss=0.001615
# Epoch 707: loss=0.001516
# Epoch 708: loss=0.001773
# Epoch 709: loss=0.001360
# Epoch 710: loss=0.001455
# Epoch 711: loss=0.001450
# Epoch 712: loss=0.001579
# Epoch 713: loss=0.001450
# Epoch 714: loss=0.001456
# Epoch 715: loss=0.001391
# Epoch 716: loss=0.001615
# Epoch 717: loss=0.001449
# Epoch 718: loss=0.002448
# Epoch 719: loss=0.001764
# Epoch 720: loss=0.002784
# Epoch 721: loss=0.001972
# Epoch 722: loss=0.001907
# Epoch 723: loss=0.001702
# Epoch 724: loss=0.002064
# Epoch 725: loss=0.001499
# Epoch 726: loss=0.001609
# Epoch 727: loss=0.001358
# Epoch 728: loss=0.001402
# Epoch 729: loss=0.001381
# Epoch 730: loss=0.001562
# Epoch 731: loss=0.001681
# Epoch 732: loss=0.001851
# Epoch 733: loss=0.001528
# Epoch 734: loss=0.001419
# Epoch 735: loss=0.001367
# Epoch 736: loss=0.001757
# Epoch 737: loss=0.001727
# Epoch 738: loss=0.001619
# Epoch 739: loss=0.001628
# Epoch 740: loss=0.001301
# Epoch 741: loss=0.001703
# Epoch 742: loss=0.001972
# Epoch 743: loss=0.001811
# Epoch 744: loss=0.001551
# Epoch 745: loss=0.002170
# Epoch 746: loss=0.001778
# Epoch 747: loss=0.001334
# Epoch 748: loss=0.001405
# Epoch 749: loss=0.001445
# Epoch 750: loss=0.001395
# Epoch 751: loss=0.001530
# Epoch 752: loss=0.001547
# Epoch 753: loss=0.001960
# Epoch 754: loss=0.001554
# Epoch 755: loss=0.001418
# Epoch 756: loss=0.001597
# Epoch 757: loss=0.001823
# Epoch 758: loss=0.001557
# Epoch 759: loss=0.001399
# Epoch 760: loss=0.001819
# Epoch 761: loss=0.001500
# Epoch 762: loss=0.001365
# Epoch 763: loss=0.001392
# Epoch 764: loss=0.001366
# Epoch 765: loss=0.001344
# Epoch 766: loss=0.001448
# Epoch 767: loss=0.001524
# Epoch 768: loss=0.001373
# Epoch 769: loss=0.001338
# Epoch 770: loss=0.001265
# Epoch 771: loss=0.001598
# Epoch 772: loss=0.001380
# Epoch 773: loss=0.001376
# Epoch 774: loss=0.001247
# Epoch 775: loss=0.001451
# Epoch 776: loss=0.001471
# Epoch 777: loss=0.001636
# Epoch 778: loss=0.001475
# Epoch 779: loss=0.001976
# Epoch 780: loss=0.001593
# Epoch 781: loss=0.001523
# Epoch 782: loss=0.001384
# Epoch 783: loss=0.001495
# Epoch 784: loss=0.001577
# Epoch 785: loss=0.001279
# Epoch 786: loss=0.001415
# Epoch 787: loss=0.001561
# Epoch 788: loss=0.001378
# Epoch 789: loss=0.001758
# Epoch 790: loss=0.001532
# Epoch 791: loss=0.001454
# Epoch 792: loss=0.002059
# Epoch 793: loss=0.001423
# Epoch 794: loss=0.001577
# Epoch 795: loss=0.001767
# Epoch 796: loss=0.001351
# Epoch 797: loss=0.001698
# Epoch 798: loss=0.001555
# Epoch 799: loss=0.001735
# Epoch 800: loss=0.001494
# Epoch 801: loss=0.001944
# Epoch 802: loss=0.001532
# Epoch 803: loss=0.002082
# Epoch 804: loss=0.001579
# Epoch 805: loss=0.001858
# Epoch 806: loss=0.001646
# Epoch 807: loss=0.001599
# Epoch 808: loss=0.001318
# Epoch 809: loss=0.001370
# Epoch 810: loss=0.001528
# Epoch 811: loss=0.001400
# Epoch 812: loss=0.001429
# Epoch 813: loss=0.001477
# Epoch 814: loss=0.001260
# Epoch 815: loss=0.001756
# Epoch 816: loss=0.001470
# Epoch 817: loss=0.002025
# Epoch 818: loss=0.001557
# Epoch 819: loss=0.001812
# Epoch 820: loss=0.001587
# Epoch 821: loss=0.001349
# Epoch 822: loss=0.001201
# Epoch 823: loss=0.001235
# Epoch 824: loss=0.001349
# Epoch 825: loss=0.001218
# Epoch 826: loss=0.001414
# Epoch 827: loss=0.001388
# Epoch 828: loss=0.001250
# Epoch 829: loss=0.001334
# Epoch 830: loss=0.001124
# Epoch 831: loss=0.001248
# Epoch 832: loss=0.001381
# Epoch 833: loss=0.001251
# Epoch 834: loss=0.001741
# Epoch 835: loss=0.001797
# Epoch 836: loss=0.001506
# Epoch 837: loss=0.001890
# Epoch 838: loss=0.001936
# Epoch 839: loss=0.001762
# Epoch 840: loss=0.001672
# Epoch 841: loss=0.001642
# Epoch 842: loss=0.001664
# Epoch 843: loss=0.001353
# Epoch 844: loss=0.001471
# Epoch 845: loss=0.001635
# Epoch 846: loss=0.001499
# Epoch 847: loss=0.001442
# Epoch 848: loss=0.001585
# Epoch 849: loss=0.001257
# Epoch 850: loss=0.002149
# Epoch 851: loss=0.001682
# Epoch 852: loss=0.001881
# Epoch 853: loss=0.001513
# Epoch 854: loss=0.003003
# Epoch 855: loss=0.002012
# Epoch 856: loss=0.002835
# Epoch 857: loss=0.001660
# Epoch 858: loss=0.001874
# Epoch 859: loss=0.001732
# Epoch 860: loss=0.001716
# Epoch 861: loss=0.001430
# Epoch 862: loss=0.001311
# Epoch 863: loss=0.001280
# Epoch 864: loss=0.001335
# Epoch 865: loss=0.001320
# Epoch 866: loss=0.001376
# Epoch 867: loss=0.001177
# Epoch 868: loss=0.001427
# Epoch 869: loss=0.001333
# Epoch 870: loss=0.001683
# Epoch 871: loss=0.001573
# Epoch 872: loss=0.001616
# Epoch 873: loss=0.001283
# Epoch 874: loss=0.001346
# Epoch 875: loss=0.001264
# Epoch 876: loss=0.001480
# Epoch 877: loss=0.001653
# Epoch 878: loss=0.001549
# Epoch 879: loss=0.001572
# Epoch 880: loss=0.001364
# Epoch 881: loss=0.001898
# Epoch 882: loss=0.001393
# Epoch 883: loss=0.002059
# Epoch 884: loss=0.001711
# Epoch 885: loss=0.001517
# Epoch 886: loss=0.001338
# Epoch 887: loss=0.001743
# Epoch 888: loss=0.001598
# Epoch 889: loss=0.001416
# Epoch 890: loss=0.001312
# Epoch 891: loss=0.001232
# Epoch 892: loss=0.001292
# Epoch 893: loss=0.001384
# Epoch 894: loss=0.001460
# Epoch 895: loss=0.001521
# Epoch 896: loss=0.001612
# Epoch 897: loss=0.001489
# Epoch 898: loss=0.001681
# Epoch 899: loss=0.001526
# Epoch 900: loss=0.001338
# Epoch 901: loss=0.001268
# Epoch 902: loss=0.001049
# Epoch 903: loss=0.001452
# Epoch 904: loss=0.001679
# Epoch 905: loss=0.001222
# Epoch 906: loss=0.001483
# Epoch 907: loss=0.001342
# Epoch 908: loss=0.001300
# Epoch 909: loss=0.001526
# Epoch 910: loss=0.001430
# Epoch 911: loss=0.001669
# Epoch 912: loss=0.001533
# Epoch 913: loss=0.001787
# Epoch 914: loss=0.001428
# Epoch 915: loss=0.001582
# Epoch 916: loss=0.001455
# Epoch 917: loss=0.001443
# Epoch 918: loss=0.001278
# Epoch 919: loss=0.001282
# Epoch 920: loss=0.001580
# Epoch 921: loss=0.001457
# Epoch 922: loss=0.001351
# Epoch 923: loss=0.001429
# Epoch 924: loss=0.001329
# Epoch 925: loss=0.001100
# Epoch 926: loss=0.001244
# Epoch 927: loss=0.001365
# Epoch 928: loss=0.001227
# Epoch 929: loss=0.001179
# Epoch 930: loss=0.001362
# Epoch 931: loss=0.001240
# Epoch 932: loss=0.001426
# Epoch 933: loss=0.001632
# Epoch 934: loss=0.001394
# Epoch 935: loss=0.001819
# Epoch 936: loss=0.002126
# Epoch 937: loss=0.001475
# Epoch 938: loss=0.001520
# Epoch 939: loss=0.001638
# Epoch 940: loss=0.001194
# Epoch 941: loss=0.001662
# Epoch 942: loss=0.001386
# Epoch 943: loss=0.001480
# Epoch 944: loss=0.001591
# Epoch 945: loss=0.001328
# Epoch 946: loss=0.001560
# Epoch 947: loss=0.001749
# Epoch 948: loss=0.001335
# Epoch 949: loss=0.002007
# Epoch 950: loss=0.001418
# Epoch 951: loss=0.001796
# Epoch 952: loss=0.001970
# Epoch 953: loss=0.001444
# Epoch 954: loss=0.001552
# Epoch 955: loss=0.001672
# Epoch 956: loss=0.001655
# Epoch 957: loss=0.001779
# Epoch 958: loss=0.002040
# Epoch 959: loss=0.001681
# Epoch 960: loss=0.001388
# Epoch 961: loss=0.001324
# Epoch 962: loss=0.001501
# Epoch 963: loss=0.001640
# Epoch 964: loss=0.001810
# Epoch 965: loss=0.001409
# Epoch 966: loss=0.001289
# Epoch 967: loss=0.001127
# Epoch 968: loss=0.001211
# Epoch 969: loss=0.001386
# Epoch 970: loss=0.001212
# Epoch 971: loss=0.001268
# Epoch 972: loss=0.001234
# Epoch 973: loss=0.001379
# Epoch 974: loss=0.001239
# Epoch 975: loss=0.001375
# Epoch 976: loss=0.001408
# Epoch 977: loss=0.001282
# Epoch 978: loss=0.001243
# Epoch 979: loss=0.001148
# Epoch 980: loss=0.001286
# Epoch 981: loss=0.001313
# Epoch 982: loss=0.001337
# Epoch 983: loss=0.001087
# Epoch 984: loss=0.001277
# Epoch 985: loss=0.001391
# Epoch 986: loss=0.001402
# Epoch 987: loss=0.001581
# Epoch 988: loss=0.001351
# Epoch 989: loss=0.001920
# Epoch 990: loss=0.001560
# Epoch 991: loss=0.001533
# Epoch 992: loss=0.001240
# Epoch 993: loss=0.001399
# Epoch 994: loss=0.001364
# Epoch 995: loss=0.001380
# Epoch 996: loss=0.001613
# Epoch 997: loss=0.001645
# Epoch 998: loss=0.001477
# Epoch 999: loss=0.001402
# Epoch 1000: loss=0.001941
