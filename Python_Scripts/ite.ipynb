# %%
import torch
from torch.utils.data import Dataset
from torch.utils.data import DataLoader

# %%
data = {"Name": 3, "Age": 4, "City": 5, "Country": 6, "Occupation": 7}

# %%
class test_dataset(Dataset):
    def __init__(self, data, transform=None, target_transform=None):
        self.data = data
        self.name = list(self.data.keys())
        self.label = list(self.data.values())
        self.transform = transform
        self.target_transform = target_transform

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        return self.name[idx], self.label[idx]

# %%
train_dataloader = DataLoader(test_dataset(data), batch_size=2, shuffle=True)

# %%
train_features, train_labels = next(iter(train_dataloader))
print(f"Name: {train_features} \nLabel: {train_labels}")
# Out:
# Name: ('City', 'Age')
# Label: tensor([5, 4])

# %%
davice = torch.accelerator.current_accelerator().type if torch.accelerator.is_available() else "cpu"
print(f"Using {davice} device")
if torch.cuda.is_available() is True:
    print(f"GPU Name: {torch.cuda.get_device_name(0)}")
class Net(torch.nn.Module):
    def __init(self):
        super().__init__()
# Out:
# Using cpu device

# %%
tensor = torch.randn(3,1,2)
print(tensor)
out = torch.nn.Flatten(0)(tensor)
print(out)
# Out:
# tensor([[[-0.8205,  2.2113]],
#
#         [[-0.2681,  0.9783]],
#
#         [[-0.5980, -0.2776]]])
# tensor([-0.8205,  2.2113, -0.2681,  0.9783, -0.5980, -0.2776])
